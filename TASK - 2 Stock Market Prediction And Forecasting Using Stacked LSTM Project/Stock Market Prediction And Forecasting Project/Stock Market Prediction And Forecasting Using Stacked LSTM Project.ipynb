# %% [markdown]
# IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd
import datetime
import math
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from sklearn.metrics import mean_squared_error

# %%
Dataset = 'https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv'

# %%
df= pd.read_csv(Dataset, parse_dates = True)
df.head(10)
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
# 5  2018-09-21  235.00  237.00  227.95  233.75  234.60               5395319
# 6  2018-09-19  235.95  237.20  233.45  234.60  234.90               1362058
# 7  2018-09-18  237.90  239.25  233.50  235.50  235.05               2614794
# 8  2018-09-17  233.15  238.00  230.25  236.40  236.60               3170894
# 9  2018-09-14  223.45  236.70  223.30  234.00  233.95               6377909
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55
# 5         12589.59
# 6          3202.78
# 7          6163.70
# 8          7445.41
# 9         14784.50

# %% [markdown]
# DISPLAYING COLUMNS

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Last', 'Close', 'Total Trade Quantity',
#        'Turnover (Lacs)'],
#       dtype='object')

# %% [markdown]
# KNOWING NUMBER OF ROWS AND COLUMNS

# %%
df.shape
# Out:
# (2035, 8)

# %% [markdown]
# KNOWING THE DATATYPES OF THE COLUMNS

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2035 entries, 0 to 2034
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2035 non-null   object
#  1   Open                  2035 non-null   float64
#  2   High                  2035 non-null   float64
#  3   Low                   2035 non-null   float64
#  4   Last                  2035 non-null   float64
#  5   Close                 2035 non-null   float64
#  6   Total Trade Quantity  2035 non-null   int64
#  7   Turnover (Lacs)       2035 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 127.3+ KB

# %% [markdown]
# CHECKING WHETHER THERE IS A MISSING VALUE

# %%
df.isnull().sum()
# Out:
# Date                    0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# Total Trade Quantity    0
# Turnover (Lacs)         0
# dtype: int64

# %% [markdown]
# DESCRIBING THE DATASET

# %%
df.describe()
# Out:
#               Open         High          Low         Last       Close  \
# count  2035.000000  2035.000000  2035.000000  2035.000000  2035.00000
# mean    149.713735   151.992826   147.293931   149.474251   149.45027
# std      48.664509    49.413109    47.931958    48.732570    48.71204
# min      81.100000    82.800000    80.000000    81.000000    80.95000
# 25%     120.025000   122.100000   118.300000   120.075000   120.05000
# 50%     141.500000   143.400000   139.600000   141.100000   141.25000
# 75%     157.175000   159.400000   155.150000   156.925000   156.90000
# max     327.700000   328.750000   321.650000   325.950000   325.75000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          2.035000e+03      2035.000000
# mean           2.335681e+06      3899.980565
# std            2.091778e+06      4570.767877
# min            3.961000e+04        37.040000
# 25%            1.146444e+06      1427.460000
# 50%            1.783456e+06      2512.030000
# 75%            2.813594e+06      4539.015000
# max            2.919102e+07     55755.080000

# %% [markdown]
# DATA VISUALIZATION(PLOTTING)

# %%
# Closing Price

plt.figure(figsize=(10,6))
df['Close'].plot(kind='line',figsize=(16,7),color='r',label="Closing Price")

plt.ylabel("Price")
plt.legend(loc="upper right")
plt.title("Change in closing price over the years")
plt.grid()

# %%
# Opening Price

plt.figure(figsize=(10,6))
df['Open'].plot(kind='line',figsize=(16,7),color='y',label="Opening Price")

plt.ylabel("Price")
plt.legend(loc="upper left")
plt.title("Change in opening price over the years")
plt.grid()

# %%
# Heat Map

plt.figure(figsize=(14,8))
sns.heatmap(df.corr(), annot=True, vmin=0.5, vmax=0.7)
plt.show()
# Out:
# <ipython-input-16-447d307e3ef8>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, vmin=0.5, vmax=0.7)

# %% [markdown]
# SELLING UNITS VS TURNOVER

# %%
fig=plt.figure(figsize=(8,7))
plt.scatter(df['Total Trade Quantity'],df['Turnover (Lacs)'], alpha=0.7, edgecolor='b', color='green')
plt.xlabel("Trade Quantity (in 100000)")
plt.ylabel("Turnover (in lacs)")
plt.title(" Selling Units Vs Turnover")
plt.show()

# %%
training_set= df[['Open']]
training_set=pd.DataFrame(training_set)
training_set
# Out:
#         Open
# 0     234.05
# 1     234.55
# 2     240.00
# 3     233.30
# 4     233.55
# ...      ...
# 2030  117.60
# 2031  120.10
# 2032  121.80
# 2033  120.30
# 2034  122.10
#
# [2035 rows x 1 columns]

# %%
df1=df.reset_index()['Close']
df1
# Out:
# 0       233.75
# 1       233.25
# 2       234.25
# 3       236.10
# 4       233.30
#          ...
# 2030    118.65
# 2031    117.60
# 2032    120.65
# 2033    120.90
# 2034    121.55
# Name: Close, Length: 2035, dtype: float64

# %%
scaler=MinMaxScaler(feature_range=(0,1))
training_set_scaler=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
training_set_scaler
# Out:
# array([[0.62418301],
#        [0.62214052],
#        [0.62622549],
#        ...,
#        [0.1621732 ],
#        [0.16319444],
#        [0.16584967]])

# %%
train_size1= int(len(training_set_scaler)*0.65)
test_size1=int(len(training_set_scaler))-train_size1
train_data1,test_data1=training_set_scaler[0:train_size1,:],training_set_scaler[train_size1:len(df),:1]

# %%
train_size1
# Out:
# 1322

# %%
def create_dataset(dataset,time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
time_step=100
x_train, y_train=create_dataset(train_data1, time_step)
x_test, y_test= create_dataset(test_data1, time_step)

# %%
print(x_train.shape,y_train.shape)
# Out:
# (1221, 100) (1221,)

# %%
x_test.shape
# Out:
# (612, 100)

# %%
y_test.shape
# Out:
# (612,)

# %%
x_train = x_train.reshape(x_train.shape[0],x_train.shape[1] , 1)
x_test = x_test.reshape(x_test.shape[0],x_test.shape[1] , 1)

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(100,1)))
model.add(LSTM(50, return_sequences=True, input_shape=(100,1)))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam', metrics='acc')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# FITTING THE MODEL

# %%
model.fit(x_train, y_train, validation_data = (x_test, y_test), epochs = 75, batch_size = 64, verbose = 1)
# Out:
# Epoch 1/75
# 20/20 [==============================] - 14s 346ms/step - loss: 0.0278 - acc: 8.1900e-04 - val_loss: 0.0079 - val_acc: 0.0016
# Epoch 2/75
# 20/20 [==============================] - 7s 347ms/step - loss: 0.0037 - acc: 8.1900e-04 - val_loss: 0.0012 - val_acc: 0.0016
# Epoch 3/75
# 20/20 [==============================] - 4s 207ms/step - loss: 0.0018 - acc: 8.1900e-04 - val_loss: 9.9424e-04 - val_acc: 0.0016
# Epoch 4/75
# 20/20 [==============================] - 6s 303ms/step - loss: 0.0016 - acc: 8.1900e-04 - val_loss: 0.0012 - val_acc: 0.0016
# Epoch 5/75
# 20/20 [==============================] - 4s 209ms/step - loss: 0.0015 - acc: 8.1900e-04 - val_loss: 0.0010 - val_acc: 0.0016
# Epoch 6/75
# 20/20 [==============================] - 4s 215ms/step - loss: 0.0015 - acc: 8.1900e-04 - val_loss: 0.0013 - val_acc: 0.0016
# Epoch 7/75
# 20/20 [==============================] - 6s 282ms/step - loss: 0.0014 - acc: 8.1900e-04 - val_loss: 0.0011 - val_acc: 0.0016
# Epoch 8/75
# 20/20 [==============================] - 4s 214ms/step - loss: 0.0014 - acc: 8.1900e-04 - val_loss: 0.0013 - val_acc: 0.0016
# Epoch 9/75
# 20/20 [==============================] - 5s 244ms/step - loss: 0.0013 - acc: 8.1900e-04 - val_loss: 0.0011 - val_acc: 0.0016
# Epoch 10/75
# 20/20 [==============================] - 5s 226ms/step - loss: 0.0012 - acc: 8.1900e-04 - val_loss: 8.9735e-04 - val_acc: 0.0016
# Epoch 11/75
# 20/20 [==============================] - 4s 214ms/step - loss: 0.0015 - acc: 8.1900e-04 - val_loss: 8.8399e-04 - val_acc: 0.0016
# Epoch 12/75
# 20/20 [==============================] - 6s 299ms/step - loss: 0.0012 - acc: 8.1900e-04 - val_loss: 0.0013 - val_acc: 0.0016
# Epoch 13/75
# 20/20 [==============================] - 4s 213ms/step - loss: 0.0011 - acc: 8.1900e-04 - val_loss: 0.0010 - val_acc: 0.0016
# Epoch 14/75
# 20/20 [==============================] - 4s 207ms/step - loss: 0.0013 - acc: 8.1900e-04 - val_loss: 7.1005e-04 - val_acc: 0.0016
# Epoch 15/75
# 20/20 [==============================] - 5s 268ms/step - loss: 0.0012 - acc: 8.1900e-04 - val_loss: 7.1921e-04 - val_acc: 0.0016
# Epoch 16/75
# 20/20 [==============================] - 4s 216ms/step - loss: 0.0011 - acc: 8.1900e-04 - val_loss: 7.6836e-04 - val_acc: 0.0016
# Epoch 17/75
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0011 - acc: 8.1900e-04 - val_loss: 7.0511e-04 - val_acc: 0.0016
# Epoch 18/75
# 20/20 [==============================] - 5s 240ms/step - loss: 0.0010 - acc: 8.1900e-04 - val_loss: 7.5388e-04 - val_acc: 0.0016
# Epoch 19/75
# 20/20 [==============================] - 4s 213ms/step - loss: 0.0014 - acc: 8.1900e-04 - val_loss: 8.3209e-04 - val_acc: 0.0016
# Epoch 20/75
# 20/20 [==============================] - 6s 282ms/step - loss: 0.0011 - acc: 8.1900e-04 - val_loss: 6.7000e-04 - val_acc: 0.0016
# Epoch 21/75
# 20/20 [==============================] - 4s 205ms/step - loss: 8.5743e-04 - acc: 8.1900e-04 - val_loss: 8.3847e-04 - val_acc: 0.0016
# Epoch 22/75
# 20/20 [==============================] - 4s 209ms/step - loss: 8.3086e-04 - acc: 8.1900e-04 - val_loss: 7.4085e-04 - val_acc: 0.0016
# Epoch 23/75
# 20/20 [==============================] - 5s 280ms/step - loss: 8.3542e-04 - acc: 8.1900e-04 - val_loss: 6.3456e-04 - val_acc: 0.0016
# Epoch 24/75
# 20/20 [==============================] - 4s 210ms/step - loss: 8.1401e-04 - acc: 8.1900e-04 - val_loss: 8.2452e-04 - val_acc: 0.0016
# Epoch 25/75
# 20/20 [==============================] - 4s 219ms/step - loss: 9.9405e-04 - acc: 8.1900e-04 - val_loss: 8.2632e-04 - val_acc: 0.0016
# Epoch 26/75
# 20/20 [==============================] - 6s 291ms/step - loss: 9.9405e-04 - acc: 8.1900e-04 - val_loss: 6.1442e-04 - val_acc: 0.0016
# Epoch 27/75
# 20/20 [==============================] - 4s 206ms/step - loss: 8.6450e-04 - acc: 8.1900e-04 - val_loss: 5.5156e-04 - val_acc: 0.0016
# Epoch 28/75
# 20/20 [==============================] - 5s 251ms/step - loss: 8.6563e-04 - acc: 8.1900e-04 - val_loss: 6.8758e-04 - val_acc: 0.0016
# Epoch 29/75
# 20/20 [==============================] - 4s 215ms/step - loss: 7.4536e-04 - acc: 8.1900e-04 - val_loss: 6.3269e-04 - val_acc: 0.0016
# Epoch 30/75
# 20/20 [==============================] - 5s 248ms/step - loss: 8.6868e-04 - acc: 8.1900e-04 - val_loss: 6.8508e-04 - val_acc: 0.0016
# Epoch 31/75
# 20/20 [==============================] - 5s 275ms/step - loss: 6.9325e-04 - acc: 8.1900e-04 - val_loss: 6.5840e-04 - val_acc: 0.0016
# Epoch 32/75
# 20/20 [==============================] - 4s 207ms/step - loss: 7.0895e-04 - acc: 8.1900e-04 - val_loss: 6.9352e-04 - val_acc: 0.0016
# Epoch 33/75
# 20/20 [==============================] - 4s 216ms/step - loss: 6.6035e-04 - acc: 8.1900e-04 - val_loss: 6.9951e-04 - val_acc: 0.0016
# Epoch 34/75
# 20/20 [==============================] - 5s 273ms/step - loss: 6.4524e-04 - acc: 8.1900e-04 - val_loss: 7.8061e-04 - val_acc: 0.0016
# Epoch 35/75
# 20/20 [==============================] - 4s 217ms/step - loss: 8.7309e-04 - acc: 8.1900e-04 - val_loss: 6.0866e-04 - val_acc: 0.0016
# Epoch 36/75
# 20/20 [==============================] - 6s 280ms/step - loss: 9.0319e-04 - acc: 8.1900e-04 - val_loss: 5.5992e-04 - val_acc: 0.0016
# Epoch 37/75
# 20/20 [==============================] - 4s 212ms/step - loss: 7.3844e-04 - acc: 8.1900e-04 - val_loss: 5.5961e-04 - val_acc: 0.0016
# Epoch 38/75
# 20/20 [==============================] - 4s 212ms/step - loss: 6.1292e-04 - acc: 8.1900e-04 - val_loss: 5.9200e-04 - val_acc: 0.0016
# Epoch 39/75
# 20/20 [==============================] - 5s 277ms/step - loss: 6.0068e-04 - acc: 8.1900e-04 - val_loss: 7.4263e-04 - val_acc: 0.0016
# Epoch 40/75
# 20/20 [==============================] - 4s 215ms/step - loss: 6.2425e-04 - acc: 8.1900e-04 - val_loss: 6.2922e-04 - val_acc: 0.0016
# Epoch 41/75
# 20/20 [==============================] - 4s 216ms/step - loss: 5.9525e-04 - acc: 8.1900e-04 - val_loss: 6.5095e-04 - val_acc: 0.0016
# Epoch 42/75
# 20/20 [==============================] - 5s 272ms/step - loss: 5.8033e-04 - acc: 8.1900e-04 - val_loss: 5.9027e-04 - val_acc: 0.0016
# Epoch 43/75
# 20/20 [==============================] - 4s 215ms/step - loss: 6.6301e-04 - acc: 8.1900e-04 - val_loss: 7.5126e-04 - val_acc: 0.0016
# Epoch 44/75
# 20/20 [==============================] - 5s 265ms/step - loss: 9.6104e-04 - acc: 8.1900e-04 - val_loss: 0.0011 - val_acc: 0.0016
# Epoch 45/75
# 20/20 [==============================] - 4s 206ms/step - loss: 6.1527e-04 - acc: 8.1900e-04 - val_loss: 6.8494e-04 - val_acc: 0.0016
# Epoch 46/75
# 20/20 [==============================] - 4s 217ms/step - loss: 6.2708e-04 - acc: 8.1900e-04 - val_loss: 6.1124e-04 - val_acc: 0.0016
# Epoch 47/75
# 20/20 [==============================] - 5s 275ms/step - loss: 5.5796e-04 - acc: 8.1900e-04 - val_loss: 6.6321e-04 - val_acc: 0.0016
# Epoch 48/75
# 20/20 [==============================] - 4s 205ms/step - loss: 5.6018e-04 - acc: 8.1900e-04 - val_loss: 5.8474e-04 - val_acc: 0.0016
# Epoch 49/75
# 20/20 [==============================] - 4s 213ms/step - loss: 5.3645e-04 - acc: 8.1900e-04 - val_loss: 4.7216e-04 - val_acc: 0.0016
# Epoch 50/75
# 20/20 [==============================] - 5s 268ms/step - loss: 6.7110e-04 - acc: 8.1900e-04 - val_loss: 5.3503e-04 - val_acc: 0.0016
# Epoch 51/75
# 20/20 [==============================] - 4s 215ms/step - loss: 5.5584e-04 - acc: 8.1900e-04 - val_loss: 7.3395e-04 - val_acc: 0.0016
# Epoch 52/75
# 20/20 [==============================] - 5s 245ms/step - loss: 6.1169e-04 - acc: 8.1900e-04 - val_loss: 7.5356e-04 - val_acc: 0.0016
# Epoch 53/75
# 20/20 [==============================] - 5s 230ms/step - loss: 5.3043e-04 - acc: 8.1900e-04 - val_loss: 9.3453e-04 - val_acc: 0.0016
# Epoch 54/75
# 20/20 [==============================] - 4s 212ms/step - loss: 5.6698e-04 - acc: 8.1900e-04 - val_loss: 5.9633e-04 - val_acc: 0.0016
# Epoch 55/75
# 20/20 [==============================] - 6s 283ms/step - loss: 5.2373e-04 - acc: 8.1900e-04 - val_loss: 5.4452e-04 - val_acc: 0.0016
# Epoch 56/75
# 20/20 [==============================] - 4s 222ms/step - loss: 5.5416e-04 - acc: 8.1900e-04 - val_loss: 4.6741e-04 - val_acc: 0.0016
# Epoch 57/75
# 20/20 [==============================] - 4s 215ms/step - loss: 6.9076e-04 - acc: 8.1900e-04 - val_loss: 5.0858e-04 - val_acc: 0.0016
# Epoch 58/75
# 20/20 [==============================] - 5s 264ms/step - loss: 5.0295e-04 - acc: 8.1900e-04 - val_loss: 5.2395e-04 - val_acc: 0.0016
# Epoch 59/75
# 20/20 [==============================] - 4s 218ms/step - loss: 5.0698e-04 - acc: 8.1900e-04 - val_loss: 5.8270e-04 - val_acc: 0.0016
# Epoch 60/75
# 20/20 [==============================] - 4s 223ms/step - loss: 5.2698e-04 - acc: 8.1900e-04 - val_loss: 4.2819e-04 - val_acc: 0.0016
# Epoch 61/75
# 20/20 [==============================] - 5s 264ms/step - loss: 4.9461e-04 - acc: 8.1900e-04 - val_loss: 5.8296e-04 - val_acc: 0.0016
# Epoch 62/75
# 20/20 [==============================] - 4s 219ms/step - loss: 5.1409e-04 - acc: 8.1900e-04 - val_loss: 6.1359e-04 - val_acc: 0.0016
# Epoch 63/75
# 20/20 [==============================] - 6s 284ms/step - loss: 5.4188e-04 - acc: 8.1900e-04 - val_loss: 4.2380e-04 - val_acc: 0.0016
# Epoch 64/75
# 20/20 [==============================] - 4s 221ms/step - loss: 5.7094e-04 - acc: 8.1900e-04 - val_loss: 4.7426e-04 - val_acc: 0.0016
# Epoch 65/75
# 20/20 [==============================] - 4s 209ms/step - loss: 4.8515e-04 - acc: 8.1900e-04 - val_loss: 4.5606e-04 - val_acc: 0.0016
# Epoch 66/75
# 20/20 [==============================] - 5s 269ms/step - loss: 5.4708e-04 - acc: 8.1900e-04 - val_loss: 4.5171e-04 - val_acc: 0.0016
# Epoch 67/75
# 20/20 [==============================] - 4s 212ms/step - loss: 5.1040e-04 - acc: 8.1900e-04 - val_loss: 3.9748e-04 - val_acc: 0.0016
# Epoch 68/75
# 20/20 [==============================] - 4s 210ms/step - loss: 5.1742e-04 - acc: 8.1900e-04 - val_loss: 4.3613e-04 - val_acc: 0.0016
# Epoch 69/75
# 20/20 [==============================] - 5s 265ms/step - loss: 4.5775e-04 - acc: 8.1900e-04 - val_loss: 4.3979e-04 - val_acc: 0.0016
# Epoch 70/75
# 20/20 [==============================] - 4s 211ms/step - loss: 4.3045e-04 - acc: 8.1900e-04 - val_loss: 4.2406e-04 - val_acc: 0.0016
# Epoch 71/75
# 20/20 [==============================] - 5s 254ms/step - loss: 4.2226e-04 - acc: 8.1900e-04 - val_loss: 4.3495e-04 - val_acc: 0.0016
# Epoch 72/75
# 20/20 [==============================] - 4s 221ms/step - loss: 4.3364e-04 - acc: 8.1900e-04 - val_loss: 4.7197e-04 - val_acc: 0.0016
# Epoch 73/75
# 20/20 [==============================] - 4s 209ms/step - loss: 4.0161e-04 - acc: 8.1900e-04 - val_loss: 3.7089e-04 - val_acc: 0.0016
# Epoch 74/75
# 20/20 [==============================] - 5s 272ms/step - loss: 7.6877e-04 - acc: 8.1900e-04 - val_loss: 3.2961e-04 - val_acc: 0.0016
# Epoch 75/75
# 20/20 [==============================] - 4s 207ms/step - loss: 4.2240e-04 - acc: 8.1900e-04 - val_loss: 3.8166e-04 - val_acc: 0.0016

# %% [markdown]
# MODEL PREDICTION

# %%
train_predict1=model.predict(x_train)
test_predict1=model.predict(x_test)
#Transformback to original form
train_predict1=scaler.inverse_transform(train_predict1)
test_predict1=scaler.inverse_transform(test_predict1)
# Out:
# 39/39 [==============================] - 5s 53ms/step
# 20/20 [==============================] - 1s 39ms/step

# %% [markdown]
# TRAIN MEAN SQUARED ERROR

# %%
math.sqrt(mean_squared_error(y_train,train_predict1))
# Out:
# 164.5418644850292

# %% [markdown]
# TEST MEAN SQUARED ERROR

# %%
math.sqrt(mean_squared_error(y_test,test_predict1))
# Out:
# 116.23151104286656

# %% [markdown]
# DATA VISUALIZATION(PLOTTING)

# %%
# shifting train predictions for plotting
look_back=100
trainPredictPlot = np.empty_like(training_set_scaler)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict1)+look_back, :] = train_predict1

# shifting test predictions for plotting
testPredictPlot = np.empty_like(training_set_scaler)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict1)+(look_back*2)+1:len(df1)-1, :] = test_predict1

# plotting baseline and predictions
plt.figure(figsize=(10,5))
plt.plot(scaler.inverse_transform(training_set_scaler))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
